# %% [markdown]
# FUNCTIONS PRACTISE

# %%
def greet():
    print("welcome to python")
    print("welcome to jupytor notbook")
    print("this is the third peint")

def greet_with_name(name):
    print(f"hello {name}")
    print(f"how do you do {name} ?")

def greet_with(name,location):
    print(f"Hi, {name}")
    print(f"we will meet at {location}")

import math
def paint_calc(height,width,cover):
  total_cans = math.ceil((height * width) / cover)
  print(f"You'll need {total_cans} cans of paint.")

# find prime number
is_prime = True
def find_prime(number):
    if number > 100:
        print(f"more than 100 not allowed {number}.")
        return
    if number <=1:
        print("It's not a prime number.")
        return
    if number <=3:
        print("It's a prime number.")
        return 
    if number % 2 == 0 or number % 3 == 0:
        print("It's not a prime number.")
        return
    i = 5
    while i * i <= number:
        if number % i == 0 or number % (i + 2) == 0:
            print("It's not a prime number.")
            return
        i += 6
        
    print("It's a prime number.")

# %%
# call prime
find_prime(87)

#call greet
# import random
# test_h = random.randint(1,11) # Height of wall (m)
# test_w = random.randint(1,11) # Width of wall (m)
# print(f"height: {test_h} \n width: {test_w}")
# coverage = 5
# paint_calc(height=test_h, width=test_w, cover=coverage)
#greet_with("malik","Lahore")
# keyword argument
#greet_with(location="lahore",name="malik")
#greet()
#greet_with_name("malik")
# Out:
# It's not a prime number.
