# %% [markdown]
# Dictioneries

# %%
programming_dictionary = {
    "Bug": "An error in a program that prevents the program from running as expected.",
    "Function": "A piece of code that you can easily call over and over again.",
    "Loop": "The action of doing somthing again and again"
    }

# retreiving item from dictionery
#print(programming_dictionary["Bug"])

# Adding new item to dictionery
programming_dictionary["Error"] = "when you forgot to mark the sytenx correctly."
#print(programming_dictionary)

# create an empty dictinery
empty_dictionery = {}

#wipe an exisiting dicionery
# programming_dictionary = {}
# print(programming_dictionary["Bug"])

# edit an item in dictionery
programming_dictionary["Error"] = "modified defination of error"
#print(programming_dictionary["Error"])

#Loop through the dictionery
for item in programming_dictionary:
    print(item)
    print(programming_dictionary[item])
# Out:
# Bug
# An error in a program that prevents the program from running as expected.
# Function
# A piece of code that you can easily call over and over again.
# Loop
# The action of doing somthing again and again
# Error
# modified defination of error

# %%
student_scores = {
  "Harry": 81,
  "Ron": 78,
  "Hermione": 99, 
  "Draco": 74,
  "Neville": 62,
}
# 🚨 Don't change the code above 👆
# TODO-1: Create an empty dictionary called student_grades.
student_grades = {}

# TODO-2: Write your code below to add the grades to student_grades.👇
for item in student_scores:
  if student_scores[item] >= 91:
    student_grades[item] = "Outstanding"
  elif 81<= student_scores[item] <= 90:
    student_grades[item] = "Exceeds Expectations"
  elif 71 <= student_scores[item] <= 80:
    student_grades[item] = "Acceptable"
  else:
    student_grades[item] = "Fail"

# 🚨 Don't change the code below 👇
print(student_grades)
# Out:
# {'Harry': 'Exceeds Expectations', 'Ron': 'Acceptable', 'Hermione': 'Outstanding', 'Draco': 'Acceptable', 'Neville': 'Fail'}
