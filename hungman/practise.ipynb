# %%
import random
word_list = ["aardvark", "baboon", "camel"]

#TODO-1 - Randomly choose a word from the word_list and assign it to a variable called chosen_word.
#random_index = random.randint(0,2)
#chosen_word = word_list[random_index];
chosen_word = random.choice(word_list)
print(f"Your chosen word is : {chosen_word}")
dahes_list = []
len_chosen_word = len(chosen_word)
for _ in range(len_chosen_word):
    dahes_list.append("_")
#print(dahes_list)
#TODO-2 - Ask the user to guess a letter and assign their answer to a variable called guess. Make guess lowercase.

#print(guess)
#TODO-3 - Check if the letter the user guessed (guess) is one of the letters in the chosen_word.
# for letter in chosen_word:
#     if letter == guess:
#        print('righ')
#     else:
#         print('wrong')r


#TODO-4 - replace the correct word with dashes
while "_" in dahes_list:
    #print(dahes_list)
    guess = input("please guess a letter").lower()
    for position in range(len_chosen_word):
        letter = chosen_word[position]
        if letter == guess:
            dahes_list[position] = letter
            #print(dahes_list)
    print(dahes_list)
print("You WON!")

# %%
from hangman_art import stages, logo

print(stages[0])
# Out:
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# ...
