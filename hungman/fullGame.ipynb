# %% [markdown]
# FUll HUNGMAN GAME

# %%
from replit import clear
import random
from hangman_art import stages, logo
from word_guess import word_list

end_of_game = False
#word_list = ["ardvark", "baboon", "camel"]
chosen_word = random.choice(word_list)
word_length = len(chosen_word)

lives = 6

#Testing code
print(logo)
print(f'Pssst, the solution is {chosen_word}.')

#Create blanks
display = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()

    clear()
    
    if guess in display:
        print(f"you have already guessed {guess}")

    guess_letter = False

   
    for position in range(word_length):
        letter = chosen_word[position]
        if letter == guess:
            display[position] = letter
            guess_letter = True

    print(f"{' '.join(display)}")


    if "_" not in display:
        end_of_game = True
        print("You win.")

    #TODO-3: - print the ASCII art from 'stages' that corresponds to the current number of 'lives' the user has remaining.
    if not guess_letter:
        lives -= 1
        print(stages[lives])
        print(f"you guess letter '{guess}'. that's not in the word. you lose life.")
        if lives == 0:
            end_of_game = True
            print("you lose")
# Out:
#
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# Pssst, the solution is naphtha.
# _ a _ _ _ _ a
# _ a p _ _ _ a
# _ a p _ _ _ a
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
#
# you guess letter 'c'. that's not in the word. you lose life.
# _ a p _ _ _ a
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
#
# you guess letter 'r'. that's not in the word. you lose life.
# _ a p _ _ _ a
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# you guess letter 'u'. that's not in the word. you lose life.
# _ a p _ _ _ a
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
#
# you guess letter 'r'. that's not in the word. you lose life.
# _ a p _ _ _ a
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
#
# you guess letter 'e'. that's not in the word. you lose life.
# _ a p _ _ _ a
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# =========
#
# you guess letter 'r'. that's not in the word. you lose life.
# you lose
