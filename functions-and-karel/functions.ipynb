# %% [markdown]
# Functions

# %%
num_char = len("malik")
print(num_char)
# Out:
# 5

# %% [markdown]
# Create Our Own Functions

# %%
def my_function():
    a = 3
    b = 3
    print(a + b)

my_function()
# Out:
# 6

# %% [markdown]
# While Loop and Function

# %%
def print_data():
    print("hello")

number_of_rounds = 6
while number_of_rounds > 0: #it execute when condition is true
    print_data()
    number_of_rounds -= 1
